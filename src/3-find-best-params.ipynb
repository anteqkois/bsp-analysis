# %%
# !pip3 install numpy pandas scipy matplotlib
# %load_ext autoreload
# %autoreload 2

from utils.trade import trade_simulation_test_parameters
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /Users/anteqkois/Library/Python/3.9/lib/python/site-packages (1.24.2)
# Requirement already satisfied: pandas in /Users/anteqkois/Library/Python/3.9/lib/python/site-packages (2.2.2)
# Requirement already satisfied: scipy in /Users/anteqkois/Library/Python/3.9/lib/python/site-packages (1.13.1)
# Requirement already satisfied: matplotlib in /Users/anteqkois/Library/Python/3.9/lib/python/site-packages (3.9.4)
# Requirement already satisfied: tzdata>=2022.7 in /Users/anteqkois/Library/Python/3.9/lib/python/site-packages (from pandas) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/anteqkois/Library/Python/3.9/lib/python/site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/anteqkois/Library/Python/3.9/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/anteqkois/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/anteqkois/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/anteqkois/Library/Python/3.9/lib/python/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/anteqkois/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: cycler>=0.10 in /Users/anteqkois/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pillow>=8 in /Users/anteqkois/Library/Python/3.9/lib/python/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/anteqkois/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/anteqkois/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/anteqkois/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
trade_simulation_test_parameters(
    interval='1m',
    ticker='TAOUSDT',
    # filter_min_interval_gap_to_skip=30,
    # cut_potential_trades=3000,
    # file_name='trades/trades_base',
    show_statistic=True,
    long_signal_generator_name='long_signal_min_bsp',
    trade_options={
        "back_interval_amount_for_bsp":[500, 1000, 1350, 1650, 2000, 2400, 2800],
        "past_interval_percentage": 120,
        "past_percentage_min_dropdown": -2.5,
        "tsl_trailing_stop_loss": 5,
        "tsl_stop_loss": 10,
        "tsl_take_profit": 6,
        "use_avg_price": False,
        "show_chart": True,
        "use_points_above_max": False,
        "chart_title": None
    }
)
# Out:
# Testing combination: {'back_interval_amount_for_bsp': 500, 'past_interval_percentage': 120, 'past_percentage_min_dropdown': -2.5, 'tsl_trailing_stop_loss': 5, 'tsl_stop_loss': 10, 'tsl_take_profit': 6, 'use_avg_price': False, 'show_chart': True, 'use_points_above_max': False, 'chart_title': None}
# Number of records after clean: 179907
# Number of points below min: 1673
# Number of points above max: 1605
# #long_signal_min_bsp length:179907
# Number of long entries: 1673
# Win Ratios:
# tsl: 0.8242
# all_tsl: 0.7273
#
# Statistics for only winning 1) trades 2) trades + potential filtered trades:
# traded_winning_tsl
# count    614.000000
# mean       5.757141
# std        1.733008
# min        0.018420
# 25%        6.041846
# 50%        6.134364
# 75%        6.335644
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# all_winning_tsl
# count    1216.000000
# mean        5.754820
# std         1.700318
# min         0.017039
# 25%         6.047413
# 50%         6.142854
# 75%         6.314954
# max        10.529412
# Name: tsl_percentage_result, dtype: float64
#
# Statistics for all (winning + lost) 1) trades 2) trades + potential filtered trades:
# traded_tsl
# count    745.000000
# mean       3.059801
# std        6.090573
# min      -10.000000
# 25%        6.000000
# 50%        6.088005
# 75%        6.262026
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# all_tsl
# count    1672.000000
# mean        1.548782
# std         7.068244
# min       -10.000000
# 25%       -10.000000
# 50%         6.070334
# 75%         6.229235
# max        10.529412
# Name: tsl_percentage_result, dtype: float64
#
# Time taken for transactions: 14.47 seconds
# Testing combination: {'back_interval_amount_for_bsp': 1000, 'past_interval_percentage': 120, 'past_percentage_min_dropdown': -2.5, 'tsl_trailing_stop_loss': 5, 'tsl_stop_loss': 10, 'tsl_take_profit': 6, 'use_avg_price': False, 'show_chart': True, 'use_points_above_max': False, 'chart_title': None}
# Number of records after clean: 179907
# Number of points below min: 898
# Number of points above max: 928
# #long_signal_min_bsp length:179907
# Number of long entries: 898
# Win Ratios:
# tsl: 0.8159
# all_tsl: 0.7238
#
# Statistics for only winning 1) trades 2) trades + potential filtered trades:
# traded_winning_tsl
# count    350.000000
# mean       5.780708
# std        1.634896
# min        0.019088
# 25%        6.039104
# 50%        6.118801
# 75%        6.272102
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# all_winning_tsl
# count    650.000000
# mean       5.736969
# std        1.684529
# min        0.018755
# 25%        6.044769
# 50%        6.134516
# 75%        6.291559
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# Statistics for all (winning + lost) 1) trades 2) trades + potential filtered trades:
# traded_tsl
# count    429.000000
# mean       2.946241
# std        6.181041
# min      -10.000000
# 25%        6.000000
# 50%        6.081081
# 75%        6.219374
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# all_tsl
# count    898.000000
# mean       1.478794
# std        7.078625
# min      -10.000000
# 25%      -10.000000
# 50%        6.064144
# 75%        6.212344
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# Time taken for transactions: 7.80 seconds
# Testing combination: {'back_interval_amount_for_bsp': 1350, 'past_interval_percentage': 120, 'past_percentage_min_dropdown': -2.5, 'tsl_trailing_stop_loss': 5, 'tsl_stop_loss': 10, 'tsl_take_profit': 6, 'use_avg_price': False, 'show_chart': True, 'use_points_above_max': False, 'chart_title': None}
# Number of records after clean: 179907
# Number of points below min: 731
# Number of points above max: 719
# #long_signal_min_bsp length:179907
# Number of long entries: 731
# Win Ratios:
# tsl: 0.8237
# all_tsl: 0.7278
#
# Statistics for only winning 1) trades 2) trades + potential filtered trades:
# traded_winning_tsl
# count    299.000000
# mean       5.770568
# std        1.666651
# min        0.019088
# 25%        6.035270
# 50%        6.122023
# 75%        6.289392
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# all_winning_tsl
# count    532.000000
# mean       5.752219
# std        1.672944
# min        0.018755
# 25%        6.043267
# 50%        6.129964
# 75%        6.289827
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# Statistics for all (winning + lost) 1) trades 2) trades + potential filtered trades:
# traded_tsl
# count    363.000000
# mean       3.074625
# std        6.061338
# min      -10.000000
# 25%        6.000000
# 50%        6.081291
# 75%        6.236491
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# all_tsl
# count    731.000000
# mean       1.545718
# std        7.059257
# min      -10.000000
# 25%      -10.000000
# 50%        6.063008
# 75%        6.212023
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# Time taken for transactions: 10.10 seconds
# Testing combination: {'back_interval_amount_for_bsp': 1650, 'past_interval_percentage': 120, 'past_percentage_min_dropdown': -2.5, 'tsl_trailing_stop_loss': 5, 'tsl_stop_loss': 10, 'tsl_take_profit': 6, 'use_avg_price': False, 'show_chart': True, 'use_points_above_max': False, 'chart_title': None}
# Number of records after clean: 179907
# Number of points below min: 597
# Number of points above max: 589
# #long_signal_min_bsp length:179907
# Number of long entries: 597
# Win Ratios:
# tsl: 0.8514
# all_tsl: 0.7722
#
# Statistics for only winning 1) trades 2) trades + potential filtered trades:
# traded_winning_tsl
# count    275.000000
# mean       5.779548
# std        1.665956
# min        0.019088
# 25%        6.038876
# 50%        6.122023
# 75%        6.289972
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# all_winning_tsl
# count    461.000000
# mean       5.743123
# std        1.694813
# min        0.018755
# 25%        6.044155
# 50%        6.129659
# 75%        6.289101
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# Statistics for all (winning + lost) 1) trades 2) trades + potential filtered trades:
# traded_tsl
# count    323.000000
# mean       3.515220
# std        5.675910
# min      -10.000000
# 25%        6.002757
# 50%        6.089289
# 75%        6.244541
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# all_tsl
# count    597.000000
# mean       2.218230
# std        6.687059
# min      -10.000000
# 25%        0.234375
# 50%        6.080273
# 75%        6.226378
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# Time taken for transactions: 6.30 seconds
# Testing combination: {'back_interval_amount_for_bsp': 2000, 'past_interval_percentage': 120, 'past_percentage_min_dropdown': -2.5, 'tsl_trailing_stop_loss': 5, 'tsl_stop_loss': 10, 'tsl_take_profit': 6, 'use_avg_price': False, 'show_chart': True, 'use_points_above_max': False, 'chart_title': None}
# Number of records after clean: 179907
# Number of points below min: 527
# Number of points above max: 519
# #long_signal_min_bsp length:179907
# Number of long entries: 527
# Win Ratios:
# tsl: 0.8378
# all_tsl: 0.7932
#
# Statistics for only winning 1) trades 2) trades + potential filtered trades:
# traded_winning_tsl
# count    248.000000
# mean       5.735823
# std        1.747397
# min        0.019088
# 25%        6.038481
# 50%        6.123848
# 75%        6.296641
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# all_winning_tsl
# count    418.000000
# mean       5.712267
# std        1.752523
# min        0.018755
# 25%        6.043848
# 50%        6.133238
# 75%        6.296576
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# Statistics for all (winning + lost) 1) trades 2) trades + potential filtered trades:
# traded_tsl
# count    296.000000
# mean       3.272042
# std        5.869396
# min      -10.000000
# 25%        6.000251
# 50%        6.087382
# 75%        6.247829
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# all_tsl
# count    527.000000
# mean       2.511894
# std        6.483873
# min      -10.000000
# 25%        0.361700
# 50%        6.083796
# 75%        6.242197
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# Time taken for transactions: 5.18 seconds
# Testing combination: {'back_interval_amount_for_bsp': 2400, 'past_interval_percentage': 120, 'past_percentage_min_dropdown': -2.5, 'tsl_trailing_stop_loss': 5, 'tsl_stop_loss': 10, 'tsl_take_profit': 6, 'use_avg_price': False, 'show_chart': True, 'use_points_above_max': False, 'chart_title': None}
# Number of records after clean: 179907
# Number of points below min: 444
# Number of points above max: 419
# #long_signal_min_bsp length:179907
# Number of long entries: 444
# Win Ratios:
# tsl: 0.8333
# all_tsl: 0.7815
#
# Statistics for only winning 1) trades 2) trades + potential filtered trades:
# traded_winning_tsl
# count    215.000000
# mean       5.829572
# std        1.625257
# min        0.019088
# 25%        6.039104
# 50%        6.137184
# 75%        6.335888
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# all_winning_tsl
# count    347.000000
# mean       5.800292
# std        1.642359
# min        0.019088
# 25%        6.046764
# 50%        6.141367
# 75%        6.311406
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# Statistics for all (winning + lost) 1) trades 2) trades + potential filtered trades:
# traded_tsl
# count    258.000000
# mean       3.292242
# std        5.915694
# min      -10.000000
# 25%        6.001399
# 50%        6.092238
# 75%        6.267483
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# all_tsl
# count    444.000000
# mean       2.407076
# std        6.609630
# min      -10.000000
# 25%        0.357479
# 50%        6.086614
# 75%        6.255954
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# Time taken for transactions: 4.76 seconds
# Testing combination: {'back_interval_amount_for_bsp': 2800, 'past_interval_percentage': 120, 'past_percentage_min_dropdown': -2.5, 'tsl_trailing_stop_loss': 5, 'tsl_stop_loss': 10, 'tsl_take_profit': 6, 'use_avg_price': False, 'show_chart': True, 'use_points_above_max': False, 'chart_title': None}
# Number of records after clean: 179907
# Number of points below min: 373
# Number of points above max: 382
# #long_signal_min_bsp length:179907
# Number of long entries: 373
# Win Ratios:
# tsl: 0.8306
# all_tsl: 0.7721
#
# Statistics for only winning 1) trades 2) trades + potential filtered trades:
# traded_winning_tsl
# count    206.000000
# mean       5.813729
# std        1.658109
# min        0.019088
# 25%        6.040265
# 50%        6.135919
# 75%        6.338079
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# all_winning_tsl
# count    288.000000
# mean       5.860796
# std        1.525707
# min        0.019088
# 25%        6.045889
# 50%        6.134433
# 75%        6.290528
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# Statistics for all (winning + lost) 1) trades 2) trades + potential filtered trades:
# traded_tsl
# count    248.000000
# mean       3.240599
# std        5.948623
# min      -10.000000
# 25%        6.001031
# 50%        6.092238
# 75%        6.272616
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# all_tsl
# count    373.000000
# mean       2.316219
# std        6.695751
# min      -10.000000
# 25%        0.365854
# 50%        6.080273
# 75%        6.236297
# max       10.529412
# Name: tsl_percentage_result, dtype: float64
#
# Time taken for transactions: 3.84 seconds
#
# Best Configuration Based on TSL Win Ratio:
# {'trade_options': {'back_interval_amount_for_bsp': 1650, 'past_interval_percentage': 120, 'past_percentage_min_dropdown': -2.5, 'tsl_trailing_stop_loss': 5, 'tsl_stop_loss': 10, 'tsl_take_profit': 6, 'use_avg_price': False, 'show_chart': True, 'use_points_above_max': False, 'chart_title': None}, 'win_ratio': np.float64(0.8514)}
#
# Best Configuration Based on All TSL Win Ratio:
# {'trade_options': {'back_interval_amount_for_bsp': 2000, 'past_interval_percentage': 120, 'past_percentage_min_dropdown': -2.5, 'tsl_trailing_stop_loss': 5, 'tsl_stop_loss': 10, 'tsl_take_profit': 6, 'use_avg_price': False, 'show_chart': True, 'use_points_above_max': False, 'chart_title': None}, 'win_ratio': np.float64(0.7932)}
# {'tsl': {'trade_options': {'back_interval_amount_for_bsp': 1650,
#    'past_interval_percentage': 120,
#    'past_percentage_min_dropdown': -2.5,
#    'tsl_trailing_stop_loss': 5,
#    'tsl_stop_loss': 10,
#    'tsl_take_profit': 6,
#    'use_avg_price': False,
#    'show_chart': True,
#    'use_points_above_max': False,
#    'chart_title': None},
#   'win_ratio': np.float64(0.8514)},
#  'all_tsl': {'trade_options': {'back_interval_amount_for_bsp': 2000,
#    'past_interval_percentage': 120,
#    'past_percentage_min_dropdown': -2.5,
#    'tsl_trailing_stop_loss': 5,
#    'tsl_stop_loss': 10,
#    'tsl_take_profit': 6,
#    'use_avg_price': False,
#    'show_chart': True,
#    'use_points_above_max': False,
#    'chart_title': None},
#   'win_ratio': np.float64(0.7932)}}
